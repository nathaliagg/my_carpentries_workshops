# %% [markdown]
# # 05/31/2019
#
# ## Software Carpentry Workshop
#
# ### Day 2 - Python with NATHY

# %% [markdown]
# # 05/31/2019
#
# ## Software Carpentry Workshop
#
# ### Day 2 - Python with NATHY

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Goals:</b>
#
# 1. Use `pandas` (Python library) for statistics
#
# 2. Visualize data in publication quality plots
#
# 3. Automate tasks
# </div>

# %% [markdown]
# **Useful links:**
# - Software Carpentry Lesson: http://swcarpentry.github.io/python-novice-gapminder/
# - Gapminder: https://www.gapminder.org
# - Pandas Cheat Sheet: https://ugoproto.github.io/ugo_py_doc/Pandas_DataFrame_Notes.pdf

# %% [markdown]
# # 1 - Workspace organization...
#
# + Create a folder on your desktop
# + Launch Jupyter and navigate to folder
# + Download data:
# http://swcarpentry.github.io/python-novice-gapminder/files/python-novice-gapminder-data.zip

# %% [markdown]
# # 2 - Import data into DataFrames

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Information about the data:</b>
# - Gross domestic product (GDP) per capita or income per person
# - GDP/capita: per country per year (1952 to 2007)
# </div>

# %%
cd data/
# Out:
# /Users/grachetng/Carpentry_Workshops_at_OSU/python_may30-31_tulsa/data

# %%
ls
# Out:
# gapminder_all.csv           gapminder_gdp_asia.csv
# gapminder_gdp_africa.csv    gapminder_gdp_europe.csv
# gapminder_gdp_americas.csv  gapminder_gdp_oceania.csv

# %%
import pandas as pd

# %% [markdown]
# Create a variable that will contain the dataframe.
# Choose a name that is informative (df = panda dataframe, oceania = gapminder_gdp_oceania.csv)

# %%
dfoceania=pd.read_csv('gapminder_gdp_oceania.csv',index_col='country')

# %%
dfoceania.head()
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
dfoceania.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
dfoceania.columns # this is a variable that has the columns names stored in it; don't use () bc it's not a method
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %% [markdown]
# # 3 - Obtain summary statistics

# %%
dfoceania.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %% [markdown]
# # 4 - Save to file

# %% [markdown]
# `to_csv`, create a NEW file name, otherwise will overwrite the files we downloaded!

# %%
dfoceania.describe().to_csv('oceania_summ_stats.csv')

# %%
ls
# Out:
# gapminder_all.csv           gapminder_gdp_europe.csv
# gapminder_gdp_africa.csv    gapminder_gdp_oceania.csv
# gapminder_gdp_americas.csv  oceania_summ_stats.csv
# gapminder_gdp_asia.csv

# %% [markdown]
# # CHEEKY EXERCISES!
#
# # 1. Import `gapminder_gdp_americas.csv`, and save summary statistics to file
#
# # 2. Transpose dataframe, and save to file

# %% [markdown]
# **SOLUTIONS:**

# %% [markdown]
# ## 1

# %%
dfamericas=pd.read_csv('gapminder_gdp_americas.csv', index_col='country')
dfamericas.head()
dfamericas.describe()
dfamericas.describe().to_csv('americas_summ_stats.csv')

# %%
ls
# Out:
# americas_summ_stats.csv     gapminder_gdp_asia.csv
# gapminder_all.csv           gapminder_gdp_europe.csv
# gapminder_gdp_africa.csv    gapminder_gdp_oceania.csv
# gapminder_gdp_americas.csv  oceania_summ_stats.csv

# %% [markdown]
# ## 2

# %%
dfamericas.T
dfamericas.T.describe().to_csv('americasT_summ_stats.csv')

# %%
ls
# Out:
# americasT_summ_stats.csv    gapminder_gdp_asia.csv
# americas_summ_stats.csv     gapminder_gdp_europe.csv
# gapminder_all.csv           gapminder_gdp_oceania.csv
# gapminder_gdp_africa.csv    oceania_summ_stats.csv
# gapminder_gdp_americas.csv

# %% [markdown]
# # 5 - Slicing and selecting values

# %% [markdown]
# **Quick recap of list, index and slicing**

# %%
fruits=['orange','strawberry','banana','mango']

# %%
fruits[2]
# Out:
# 'banana'

# %%
fruits[1:3]
# Out:
# ['strawberry', 'banana']

# %%
fruits[1:] # nothing means to the end of the list
# Out:
# ['strawberry', 'banana', 'mango']

# %%
basket=fruits[1:3]

# %%
basket
# Out:
# ['strawberry', 'banana']

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Pandas Dataframe:</b>
# - 2-dimensional representation of a table
# - Series is the data-structure Pandas use to represent a column.
# </div>
#
#
# Because it's a 2D, have to tell which rows and which columns want to select.
# Let's use the `americas`

# %%
dfamericas.head()
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
# Canada     Americas    11367.161120    12489.950060    13462.485550
# Chile      Americas     3939.978789     4315.622723     4519.094331
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
# Canada       16076.588030    18970.570860    22090.883060    22898.792140
# Chile         5106.654313     5494.024437     4756.763836     5095.665738
#
#            gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# ...

# %% [markdown]
# **`.loc[]` to select values by the name**
#
#
# **`.loc[a:b,i:j]`**, where
#     a and b are the rows/countries
#     i and j are the columns/years

# %%
dfamericas.loc['Brazil'] # just the row that has 'Brazil'
# Out:
# continent         Americas
# gdpPercap_1952     2108.94
# gdpPercap_1957     2487.37
# gdpPercap_1962     3336.59
# gdpPercap_1967     3429.86
# gdpPercap_1972     4985.71
# gdpPercap_1977     6660.12
# gdpPercap_1982     7030.84
# gdpPercap_1987      7807.1
# gdpPercap_1992     6950.28
# gdpPercap_1997     7957.98
# gdpPercap_2002     8131.21
# gdpPercap_2007      9065.8
# Name: Brazil, dtype: object

# %%
dfamericas.loc["Brazil":,] # All rows from Brazil to the end, all years
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# Guatemala            Americas     2428.237769     2617.155967     2750.364446
# Haiti                Americas     1840.366939     1726.887882     1796.589032
# ...

# %%
dfamericas.loc[:,'gdpPercap_2002':] # All countries, years 2002 to end
# Out:
#                      gdpPercap_2002  gdpPercap_2007
# country
# Argentina               8797.640716    12779.379640
# Bolivia                 3413.262690     3822.137084
# Brazil                  8131.212843     9065.800825
# Canada                 33328.965070    36319.235010
# Chile                  10778.783850    13171.638850
# Colombia                5755.259962     7006.580419
# Costa Rica              7723.447195     9645.061420
# Cuba                    6340.646683     8948.102923
# Dominican Republic      4563.808154     6025.374752
# Ecuador                 5773.044512     6873.262326
# El Salvador             5351.568666     5728.353514
# Guatemala               4858.347495     5186.050003
# Haiti                   1270.364932     1201.637154
# Honduras                3099.728660     3548.330846
# Jamaica                 6994.774861     7320.880262
# Mexico                 10742.440530    11977.574960
# Nicaragua               2474.548819     2749.320965
# ...

# %%
dfamericas.loc['Ecuador':'Jamaica','gdpPercap_1997':'gdpPercap_2002']
# Out:
#              gdpPercap_1997  gdpPercap_2002
# country
# Ecuador         7429.455877     5773.044512
# El Salvador     5154.825496     5351.568666
# Guatemala       4684.313807     4858.347495
# Haiti           1341.726931     1270.364932
# Honduras        3160.454906     3099.728660
# Jamaica         7121.924704     6994.774861

# %% [markdown]
# We selected part of the data that is of interest...

# %%
dfamericas.loc['Ecuador':'Jamaica','gdpPercap_1997':'gdpPercap_2002'].min()
# Out:
# gdpPercap_1997    1341.726931
# gdpPercap_2002    1270.364932
# dtype: float64

# %%
dfamericas.loc['Ecuador':'Jamaica','gdpPercap_1997':'gdpPercap_2002'].max()
# Out:
# gdpPercap_1997    7429.455877
# gdpPercap_2002    6994.774861
# dtype: float64

# %%
dfamericas.loc['Ecuador':'Jamaica','gdpPercap_1997':'gdpPercap_2002'].describe()
# Out:
#        gdpPercap_1997  gdpPercap_2002
# count        6.000000        6.000000
# mean      4815.450287     4557.971521
# std       2327.702104     2052.767126
# min       1341.726931     1270.364932
# 25%       3541.419631     3539.383369
# 50%       4919.569651     5104.958080
# 75%       6630.149902     5667.675550
# max       7429.455877     6994.774861

# %%
dfamericas.loc['Ecuador':'Jamaica','gdpPercap_1997':'gdpPercap_2002'].T.describe()
# Out:
# country      Ecuador  El Salvador    Guatemala        Haiti     Honduras  \
# count       2.000000     2.000000     2.000000     2.000000     2.000000
# mean     6601.250194  5253.197081  4771.330651  1306.045932  3130.091783
# std      1171.259709   139.118430   123.060401    50.460553    42.939940
# min      5773.044512  5154.825496  4684.313807  1270.364932  3099.728660
# 25%      6187.147353  5204.011288  4727.822229  1288.205432  3114.910222
# 50%      6601.250194  5253.197081  4771.330651  1306.045932  3130.091783
# 75%      7015.353036  5302.382873  4814.839073  1323.886431  3145.273345
# max      7429.455877  5351.568666  4858.347495  1341.726931  3160.454906
#
# country      Jamaica
# count       2.000000
# mean     7058.349783
# std        89.908516
# min      6994.774861
# 25%      7026.562322
# 50%      7058.349783
# 75%      7090.137243
# max      7121.924704

# %%
dfamericas.loc[['Brazil','Ecuador'],'gdpPercap_1997':'gdpPercap_2002']
# Out:
#          gdpPercap_1997  gdpPercap_2002
# country
# Brazil      7957.980824     8131.212843
# Ecuador     7429.455877     5773.044512

# %% [markdown]
# **`.iloc[]` to select values by the index**
#
#
# **`.iloc[a:b,i:j]`**, where
#     a and b are the indexes of rows
#     i and j are the indexes of columns

# %%
dfamericas.iloc[9:16,-3:-1]
# Out:
#              gdpPercap_1997  gdpPercap_2002
# country
# Ecuador         7429.455877     5773.044512
# El Salvador     5154.825496     5351.568666
# Guatemala       4684.313807     4858.347495
# Haiti           1341.726931     1270.364932
# Honduras        3160.454906     3099.728660
# Jamaica         7121.924704     6994.774861
# Mexico          9767.297530    10742.440530

# %% [markdown]
# **Observation:**
# ```
#     1:3, omits the final index (i.e. index 3) in the range provided, while a named slice, ‘gdpPercap_1952’:’gdpPercap_1962’, includes the final element.
#     ```

# %%
dfamericas.iloc[[9,15],-3:-1]
# Out:
#          gdpPercap_1997  gdpPercap_2002
# country
# Ecuador     7429.455877     5773.044512
# Mexico      9767.297530    10742.440530

# %% [markdown]
# **Selecting data based on value**

# %%
subset_americas=dfamericas.loc['Ecuador':'Jamaica','gdpPercap_1997':]

# %%
subset_americas.head()
# Out:
#              gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Ecuador         7429.455877     5773.044512     6873.262326
# El Salvador     5154.825496     5351.568666     5728.353514
# Guatemala       4684.313807     4858.347495     5186.050003
# Haiti           1341.726931     1270.364932     1201.637154
# Honduras        3160.454906     3099.728660     3548.330846

# %% [markdown]
# # 6 - Mask values

# %% [markdown]
# Mask values that are not important, maks outliers, or highlight some values...
#
# 2 ways to do it

# %%
subset_americas
# Out:
#              gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Ecuador         7429.455877     5773.044512     6873.262326
# El Salvador     5154.825496     5351.568666     5728.353514
# Guatemala       4684.313807     4858.347495     5186.050003
# Haiti           1341.726931     1270.364932     1201.637154
# Honduras        3160.454906     3099.728660     3548.330846
# Jamaica         7121.924704     6994.774861     7320.880262

# %%
mask=subset_americas >=3500
subset_americas[mask] # 1way
# Out:
#              gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Ecuador         7429.455877     5773.044512     6873.262326
# El Salvador     5154.825496     5351.568666     5728.353514
# Guatemala       4684.313807     4858.347495     5186.050003
# Haiti                   NaN             NaN             NaN
# Honduras                NaN             NaN     3548.330846
# Jamaica         7121.924704     6994.774861     7320.880262

# %%
subset_americas[subset_americas >=3500] # 2way
# Out:
#              gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Ecuador         7429.455877     5773.044512     6873.262326
# El Salvador     5154.825496     5351.568666     5728.353514
# Guatemala       4684.313807     4858.347495     5186.050003
# Haiti                   NaN             NaN             NaN
# Honduras                NaN             NaN     3548.330846
# Jamaica         7121.924704     6994.774861     7320.880262

# %%
subset_americas[subset_americas >=3500].describe()
# Out:
#        gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# count        4.000000        4.000000        5.000000
# mean      6097.629971     5744.433883     5731.375390
# std       1379.526827      913.539507     1491.098916
# min       4684.313807     4858.347495     3548.330846
# 25%       5037.197574     5228.263373     5186.050003
# 50%       6138.375100     5562.306589     5728.353514
# 75%       7198.807497     6078.477099     6873.262326
# max       7429.455877     6994.774861     7320.880262

# %%
subset_americas[subset_americas >=3500].T.describe()
# Out:
# country      Ecuador  El Salvador    Guatemala  Haiti     Honduras  \
# count       3.000000     3.000000     3.000000    0.0     1.000000
# mean     6691.920905  5411.582559  4909.570435    NaN  3548.330846
# std       842.963929   291.435837   254.759975    NaN          NaN
# min      5773.044512  5154.825496  4684.313807    NaN  3548.330846
# 25%      6323.153419  5253.197081  4771.330651    NaN  3548.330846
# 50%      6873.262326  5351.568666  4858.347495    NaN  3548.330846
# 75%      7151.359102  5539.961090  5022.198749    NaN  3548.330846
# max      7429.455877  5728.353514  5186.050003    NaN  3548.330846
#
# country      Jamaica
# count       3.000000
# mean     7145.859942
# std       164.365005
# min      6994.774861
# 25%      7058.349783
# 50%      7121.924704
# 75%      7221.402483
# max      7320.880262

# %% [markdown]
# # CHEEKY EXERCISES!
#
# # 3. Slice `americas` to select `Paraguay` to `Uruguay` and `1962` to `1972`, mask values less than `8,000`, obtain summary statistics by country, and save to file.

# %%
subset_americas2=dfamericas.loc['Paraguay':'Uruguay','gdpPercap_1962':'gdpPercap_1972']
subset_americas2[subset_americas2 >=5000].T.describe().to_csv('americassubset2T_summ_stats.csv')

# %% [markdown]
# # 7 - Plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
time=[0,1,2,3,4]
position=[0,100,200,300,400]
plt.plot(time,position)
plt.xlabel('Time h')
plt.ylabel('Position km')
# Out:
# Text(0, 0.5, 'Position km')

# %% [markdown]
# Let's use `oceania` df
#
# 1. Fix the years (remove gdpPercap_)
# 2. Replace column headers
# 3. Plot Australia data
# 4. Explore customization

# %%
years=dfoceania.columns.str.strip('gdpPercap_')  # getting just the years and stripping gdpPercap_

# %%
years
# Out:
# Index(['1952', '1957', '1962', '1967', '1972', '1977', '1982', '1987', '1992',
#        '1997', '2002', '2007'],
#       dtype='object')

# %%
dfoceania.columns=years.astype(str) # replacing column headers

# %%
dfoceania.columns
# Out:
# Index(['1952', '1957', '1962', '1967', '1972', '1977', '1982', '1987', '1992',
#        '1997', '2002', '2007'],
#       dtype='object')

# %% [markdown]
# We'll plot data now.
# 2 ways to do it.

# %%
# 1 way
dfoceania.loc['Australia'].plot() 
plt.xlabel('Year')
plt.ylabel('GDP per capita, $1,000')
plt.title('GAPMINDER')
plt.legend()

# %%
# 2 way
gdp_australia=dfoceania.loc['Australia']
plt.plot(years,gdp_australia)
plt.xlabel('Year')
plt.ylabel('GDP per capita, $1,000')
plt.title('GAPMINDER')
# Out:
# Text(0.5, 1.0, 'GAPMINDER')

# %%
plt.plot(years,gdp_australia,'g--') # g == green; -- dashed line style
plt.title('GAPMINDER')
# Out:
# Text(0.5, 1.0, 'GAPMINDER')

# %%
plt.plot(years,gdp_australia,'k:') # k == black; : dotted line
plt.title('GAPMINDER')
# Out:
# Text(0.5, 1.0, 'GAPMINDER')

# %%
plt.plot(years, gdp_australia, 'rD')
plt.title('GAPMINDER')
# Out:
# Text(0.5, 1.0, 'GAPMINDER')

# %%
plt.plot(years, gdp_australia, 'rD-')
plt.title('GAPMINDER')
# Out:
# Text(0.5, 1.0, 'GAPMINDER')

# %%
plt.plot?

# %%
dfoceania
# Out:
#                     1952         1957         1962         1967         1972  \
# country
# Australia    10039.59564  10949.64959  12217.22686  14526.12465  16788.62948
# New Zealand  10556.57566  12247.39532  13175.67800  14463.91893  16046.03728
#
#                     1977         1982         1987         1992         1997  \
# country
# Australia    18334.19751  19477.00928  21888.88903  23424.76683  26997.93657
# New Zealand  16233.71770  17632.41040  19007.19129  18363.32494  21050.41377
#
#                     2002         2007
# country
# Australia    30687.75473  34435.36744
# New Zealand  23189.80135  25185.00911

# %% [markdown]
# \5. Plot more than one data

# %%
dfoceania.T.plot() # line plot is default
plt.xlabel('Year')
plt.ylabel('GDP per capita, $1,000')
plt.title('GAPMINDER')
#plt.legend() default is best, 1 is upper right, 2 upper left
plt.legend(loc=1)

# %%
dfoceania.T.plot(kind='barh') # bar
plt.xlabel('Year')
plt.ylabel('GDP per capita, $1,000')
plt.title('GAPMINDER')
#plt.legend() default is best, 1 is upper right, 2 upper left
plt.legend(loc=1)

# %%
plt.style.use('ggplot')
dfoceania.T.plot(kind='barh')

# %%
print(plt.style.available)
#plt.rcParams.update(plt.rcParamsDefault)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
plt.style.use('tableau-colorblind10')
dfoceania.T.plot(kind='barh')

# %%
plt.style.use('seaborn-white')
dfoceania.T.plot(kind='barh')

# %% [markdown]
# \6. Plot country vs country in scatter plot

# %%
dfoceania.T.plot(x='Australia', y='New Zealand',kind='scatter')

# %%
dfoceania.T.plot.scatter(x='Australia', y='New Zealand')

# %%
dfoceania.T.plot(x='Australia',y='New Zealand', kind='scatter', c='green', marker='D')

# %%
help(dfoceania)
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : numpy ndarray (structured or homogeneous), dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |
#  |      .. versionchanged :: 0.23.0
#  |         If data is a dict, argument order is maintained for Python 3.6
#  |         and later.
#  |
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to RangeIndex if
#  |      no indexing information part of input data and no index provided
#  |  columns : Index or array-like
# ...

# %% [markdown]
# # 8 - Saving plot to figure

# %%
plt.style.use('tableau-colorblind10')
dfoceania.T.plot(kind='barh')
plt.savefig('oceania_1.png',dpi=200)

# %%
ls
# Out:
# americasT_summ_stats.csv         gapminder_gdp_asia.csv
# americas_summ_stats.csv          gapminder_gdp_europe.csv
# americassubset2T_summ_stats.csv  gapminder_gdp_oceania.csv
# gapminder_all.csv                oceania_1.png
# gapminder_gdp_africa.csv         oceania_summ_stats.csv
# gapminder_gdp_americas.csv

# %%
# %%bash
# open .

# %% [markdown]
# # CHEEKY EXERCISES
# # 4. Use `americas`, plot a line graph with the `min`, `mean`, and `max` GDP per capita over time for all countries, use `bmh` style, and save plot to figure

# %%
dfamericas.head()
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
# Canada     Americas    11367.161120    12489.950060    13462.485550
# Chile      Americas     3939.978789     4315.622723     4519.094331
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
# Canada       16076.588030    18970.570860    22090.883060    22898.792140
# Chile         5106.654313     5494.024437     4756.763836     5095.665738
#
#            gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# ...

# %%
# run once!!!
dfamericas = dfamericas.drop('continent', 1) 

years2=dfamericas.columns.str.strip('gdpPercap_')  # getting just the years and stripping gdpPercap_
years2
#dfamericas.columns
dfamericas.columns=years.astype(str) # replacing column headers

# %%
dfamericas.head()
# Out:
#                    1952          1957          1962          1967  \
# country
# Argentina   5911.315053   6856.856212   7133.166023   8052.953021
# Bolivia     2677.326347   2127.686326   2180.972546   2586.886053
# Brazil      2108.944355   2487.365989   3336.585802   3429.864357
# Canada     11367.161120  12489.950060  13462.485550  16076.588030
# Chile       3939.978789   4315.622723   4519.094331   5106.654313
#
#                    1972          1977          1982          1987  \
# country
# Argentina   9443.038526  10079.026740   8997.897412   9139.671389
# Bolivia     2980.331339   3548.097832   3156.510452   2753.691490
# Brazil      4985.711467   6660.118654   7030.835878   7807.095818
# Canada     18970.570860  22090.883060  22898.792140  26626.515030
# Chile       5494.024437   4756.763836   5095.665738   5547.063754
#
#                    1992          1997          2002          2007
# country
# Argentina   9308.418710  10967.281950   8797.640716  12779.379640
# ...

# %%
dfamericas.min()
# Out:
# 1952    1397.717137
# 1957    1544.402995
# 1962    1662.137359
# 1967    1452.057666
# 1972    1654.456946
# 1977    1874.298931
# 1982    2011.159549
# 1987    1823.015995
# 1992    1456.309517
# 1997    1341.726931
# 2002    1270.364932
# 2007    1201.637154
# dtype: float64

# %%
plt.style.use('bmh')
plt.plot(dfamericas.min(), label='min')
plt.plot(dfamericas.max(),label='max')
plt.plot(dfamericas.mean(),label='mean')
plt.legend(loc='best')
plt.xlabel('Years')
plt.savefig('americas_basic_stats.png')

# %%
ls
# Out:
# americasT_summ_stats.csv         gapminder_gdp_americas.csv
# americas_basic_stats.png         gapminder_gdp_asia.csv
# americas_summ_stats.csv          gapminder_gdp_europe.csv
# americassubset2T_summ_stats.csv  gapminder_gdp_oceania.csv
# gapminder_all.csv                oceania_1.png
# gapminder_gdp_africa.csv         oceania_summ_stats.csv

# %%
# # 2 way without deleting the first column

# plt.style.use('bmh')
# plt.plot(dfamericas.iloc[:,1:].min(), label='min')
# plt.plot(dfamericas.iloc[:,1:].max(),label='max')
# plt.plot(dfamericas.iloc[:,1:].mean(),label='mean')
# plt.legend(loc='best')
# plt.xlabel('Years')

# %% [markdown]
# # 5. Import `gapminder_all`
#
# ## 5a - make a histogram of the `2002-2007` GDP of all countries
#
# ## 5b - make a scatter plot of the relationship between the `2007` GDP vs life expectancy
#
# ## 5c - make 3 box plots to explore the GDP trends for the years `1997, 2002 and 2007 `

# %%
dfall = pd.read_csv('gapminder_all.csv', index_col='country')

# %%
dfall.head()
# Out:
#              continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria         Africa     2449.008185     3013.976023     2550.816880
# Angola          Africa     3520.610273     3827.940465     4269.276742
# Benin           Africa     1062.752200      959.601080      949.499064
# Botswana        Africa      851.241141      918.232535      983.653976
# Burkina Faso    Africa      543.255241      617.183465      722.512021
#
#               gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Algeria          3246.991771     4182.663766     4910.416756     5745.160213
# Angola           5522.776375     5473.288005     3008.647355     2756.953672
# Benin            1035.831411     1085.796879     1029.161251     1277.897616
# Botswana         1214.709294     2263.611114     3214.857818     4551.142150
# Burkina Faso      794.826560      854.735976      743.387037      807.198586
#
# ...

# %% [markdown]
# # A

# %%
plt.style.use('seaborn-white')
subset_all=dfall.loc[:,'gdpPercap_2002':'gdpPercap_2007']
subset_all.plot(kind='hist', bins=100,stacked=True)
plt.xlabel('GDP')
plt.ylabel('Frequency')
plt.title('Year: 2002-2007')
plt.legend()

# %% [markdown]
# # B

# %%
dfall.plot(kind='scatter', x='gdpPercap_2007', y='lifeExp_2007')

# %%
dfall.plot(kind='scatter', x='gdpPercap_2007', y='lifeExp_2007', s=dfall['pop_2007']/1e6) # add scalar of the dots
plt.savefig('all_gdp_vs_lifeExp.png')

# %%
dfall.loc[:,'gdpPercap_1997':'gdpPercap_2007']
# Out:
#                           gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Algeria                      4797.295051     5288.040382     6223.367465
# Angola                       2277.140884     2773.287312     4797.231267
# Benin                        1232.975292     1372.877931     1441.284873
# Botswana                     8647.142313    11003.605080    12569.851770
# Burkina Faso                  946.294962     1037.645221     1217.032994
# Burundi                       463.115148      446.403513      430.070692
# Cameroon                     1694.337469     1934.011449     2042.095240
# Central African Republic      740.506332      738.690607      706.016537
# Chad                         1004.961353     1156.181860     1704.063724
# Comoros                      1173.618235     1075.811558      986.147879
# Congo Dem. Rep.               312.188423      241.165877      277.551859
# Congo Rep.                   3484.164376     3484.061970     3632.557798
# ...

# %%
dfall.loc[:,'gdpPercap_1997':'gdpPercap_2007'].plot(kind='box')

# %% [markdown]
# # C

# %%
dfall.boxplot('gdpPercap_2007',by='continent')

# %% [markdown]
# **Quick recap: For loop**

# %%
fruits
# Out:
# ['orange', 'strawberry', 'banana', 'mango']

# %%
for k in fruits:
    print(k,'has',len(k),'letters.')
# Out:
# orange has 6 letters.
# strawberry has 10 letters.
# banana has 6 letters.
# mango has 5 letters.

# %%
for i in range(1,10):
    print(i,'\t',i**2)
# Out:
# 1 	 1
# 2 	 4
# 3 	 9
# 4 	 16
# 5 	 25
# 6 	 36
# 7 	 49
# 8 	 64
# 9 	 81

# %%
year4=['gdpPercap_1997','gdpPercap_2002','gdpPercap_2007']
for yr in year4:
    dfall.boxplot(yr, by='continent')

# %% [markdown]
# # 9 - Looping over data sets -- Automating tasks

# %%
import glob

# %% [markdown]
# Match files with a pattern == globbing

# %%
print(glob.glob('*.csv')) # we have extra files with summs... remove those
# Out:
# ['gapminder_gdp_americas.csv', 'gapminder_gdp_europe.csv', 'gapminder_all.csv', 'gapminder_gdp_oceania.csv', 'americas_summ_stats.csv', 'gapminder_gdp_africa.csv', 'americasT_summ_stats.csv', 'oceania_summ_stats.csv', 'americassubset2T_summ_stats.csv', 'gapminder_gdp_asia.csv']

# %%
print(glob.glob('gap*.csv'))
# Out:
# ['gapminder_gdp_americas.csv', 'gapminder_gdp_europe.csv', 'gapminder_all.csv', 'gapminder_gdp_oceania.csv', 'gapminder_gdp_africa.csv', 'gapminder_gdp_asia.csv']

# %%
for file in glob.glob('gap*.csv'):
    print(file)
# Out:
# gapminder_gdp_americas.csv
# gapminder_gdp_europe.csv
# gapminder_all.csv
# gapminder_gdp_oceania.csv
# gapminder_gdp_africa.csv
# gapminder_gdp_asia.csv

# %%
for file in glob.glob('gap*.csv'):
    dataframe=pd.read_csv(file,index_col='country')
    print(file, '\n\n',dataframe.head(),'\n\n')
# Out:
# gapminder_gdp_americas.csv
#
#            continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
# Canada     Americas    11367.161120    12489.950060    13462.485550
# Chile      Americas     3939.978789     4315.622723     4519.094331
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
# Canada       16076.588030    18970.570860    22090.883060    22898.792140
# Chile         5106.654313     5494.024437     4756.763836     5095.665738
#
# ...

# %%
print('{}\t{}\t{}\t{}'.format('Filename','Minimum','Mean','Maxima'))

for file in glob.glob('gap*.csv'):
    dataframe=pd.read_csv(file,index_col='country')
    subset=dataframe.loc[:,"gdpPercap_1952"]
    print('{}\t{}\t{}\t{}'.format(file.strip('.csv'),subset.min(),subset.mean(),subset.max()))
# Out:
# Filename	Minimum	Mean	Maxima
# gapminder_gdp_america	1397.7171369999999	4079.0625522000005	13990.482080000002
# gapminder_gdp_europe	973.5331947999999	5661.0574347599995	14734.23275
# gapminder_all	298.8462121	3725.2760457992963	108382.3529
# gapminder_gdp_oceania	10039.595640000001	10298.08565	10556.575659999999
# gapminder_gdp_africa	298.8462121	1252.5724658211539	4725.295531000001
# gapminder_gdp_asia	331.0	5195.484004030303	108382.3529

# %%
with open('loop_minTOmax.txt','w') as output:
    output.write('{}\t{}\t{}\t{}\n'.format('Filename','Minimum','Mean','Maxima'))
    for file in glob.glob('gap*.csv'):
        dataframe=pd.read_csv(file,index_col='country')
        subset=dataframe.loc[:,"gdpPercap_1952"]
        output.write('{}\t{}\t{}\t{}\n'.format(file.strip('.csv'),subset.min(),subset.mean(),subset.max()))

# %%
with open('loop_minTOmax.txt','w') as output:
    output.write('{}\t{}\t{}\t{}\n'.format('Filename','Minimum','Mean','Maxima'))
    for file in glob.glob('gapminder_gdp_*.csv'):
        dataframe=pd.read_csv(file,index_col='country')
        subset1=dataframe.loc[:,"gdpPercap_1952"]
        output.write('{}\t{}\t{}\t{}\n'.format(file.strip('.csv'),subset.min(),subset.mean(),subset.max()))
        subset2=dataframe.loc[:,'gdpPercap_2002':'gdpPercap_2007']
        subset2.plot(kind='hist', bins=100,stacked=True)
        plt.xlabel('GDP')
        plt.ylabel('Frequency')
        plot_title=file.split('_')[2].split('.')[0].title()
        plt.title(plot_title+', Year: 2002-2007')
        plt.savefig(file.strip('.csv')+'_histogram.png')
        plt.close()

# %%
plt.style.use('seaborn-white')
subset_all=dfall.loc[:,'gdpPercap_2002':'gdpPercap_2007']
subset_all.plot(kind='hist', bins=100,stacked=True)
plt.xlabel('GDP')
plt.ylabel('Frequency')
plt.title('Year: 2002-2007')
plt.legend()

# %%
ls
# Out:
# all_gdp_vs_lifeExp.png               gapminder_gdp_asia.csv
# americasT_summ_stats.csv             gapminder_gdp_asia_histogram.png
# americas_basic_stats.png             gapminder_gdp_europe.csv
# americas_summ_stats.csv              gapminder_gdp_europe_histogram.png
# americassubset2T_summ_stats.csv      gapminder_gdp_oceania.csv
# gapminder_all.csv                    gapminder_gdp_oceania_histogram.png
# gapminder_gdp_africa.csv             loop_minTOmax.txt
# gapminder_gdp_africa_histogram.png   oceania_1.png
# gapminder_gdp_america_histogram.png  oceania_summ_stats.csv
# gapminder_gdp_americas.csv

# %%
# %%bash
# open .

# %% [markdown]
# # CHALLENGE TO TAKE HOME: AUTOMATE PLOTTING DATA

# %% [markdown]
# # 10 - Functions

# %%
def temp_converter(a, b):
    if a == 'C':
        fahr=9/5*b+32
        print('Converting from Celsius to Fahrenheit')
        print('{}C is {}F'.format(b,int(fahr)))
    elif a == 'F':
        celsius=(b-32)*5/9
        print('Converting from Fahrenheit to Celsius')
        print('{}F is {}C'.format(b,int(celsius)))

# %%
temp_converter('C',25)
# Out:
# Converting from Celsius to Fahrenheit
# 25C is 77F

# %%
temp_converter('F',101)
# Out:
# Converting from Fahrenheit to Celsius
# 101F is 38C

# %%
for file in glob.glob('gapminder_gdp*.csv'):
    print(file)
# Out:
# gapminder_gdp_americas.csv
# gapminder_gdp_europe.csv
# gapminder_gdp_oceania.csv
# gapminder_gdp_africa.csv
# gapminder_gdp_asia.csv

# %%
names=[]
for file in glob.glob('gapminder_gdp*.csv'):
    names.append(file.strip('.csv').split('_')[2])

# %%
names
# Out:
# ['america', 'europe', 'oceania', 'africa', 'asia']

# %%
dataframe=pd.read_csv('gapminder_gdp_'+names[2]+'.csv',index_col='country')

# %%
dataframe.loc[:,'gdpPercap_2007'].describe()
# Out:
# count        2.000000
# mean     29810.188275
# std       6540.991104
# min      25185.009110
# 25%      27497.598692
# 50%      29810.188275
# 75%      32122.777857
# max      34435.367440
# Name: gdpPercap_2007, dtype: float64

# %%
# %run ../python_code.py asia

# %%
def analyze_my_data(a):
    dataframe=pd.read_csv('gapminder_gdp_'+a+'.csv',index_col='country')
    return dataframe.loc[:,'gdpPercap_2007'].describe()

# %%
analyze_my_data('oceania')
# Out:
# count        2.000000
# mean     29810.188275
# std       6540.991104
# min      25185.009110
# 25%      27497.598692
# 50%      29810.188275
# 75%      32122.777857
# max      34435.367440
# Name: gdpPercap_2007, dtype: float64

# %%
analyze_my_data('asia')
# Out:
# count       33.000000
# mean     12473.026870
# std      14154.937343
# min        944.000000
# 25%       2452.210407
# 50%       4471.061906
# 75%      22316.192870
# max      47306.989780
# Name: gdpPercap_2007, dtype: float64
